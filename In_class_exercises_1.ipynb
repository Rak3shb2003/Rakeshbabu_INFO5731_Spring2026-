# %% [markdown]
# <a href="https://colab.research.google.com/github/Rak3shb2003/Rakeshbabu_INFO5731_Spring2026-/blob/main/In_class_exercises_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **In-Class Assignment — Week 2 (Lesson 2)**
#
# Time: 20–30 minutes
# Points: 10
#
# **Instructions**
#
# This is an individual in-class assignment.
#
# Complete it during class time.
#
# You may use Week 2 lecture notes / demo notebooks.
#
# Write your code under each question and print the output.
#
# Submit the GitHub link.

# %% [markdown]
# ## Question 1 ( 2 point)
# Write a Python program that  prompts the user to input the length and width of a rectangle, and then calculates and displays the area of the rectangle.

# %%
# write your answer here
length = float(input("Enter the length of the rectangle: "))
width = float(input("Enter the width of the rectangle: "))

area = length * width

print(f"The area of the rectangle is: {area}")
# Out:
# Enter the length of the rectangle: 6
# Enter the width of the rectangle: 4
# The area of the rectangle is: 24.0

# %% [markdown]
# ## Question 2 ( 2 point)
# Create a Python program that interactively takes two numerical inputs from the user and swaps their values without utilizing an extra variable.

# %%
# write your answer here

a = float(input("Enter the first number: "))
b = float(input("Enter the second number: "))

print(f"Before swapping: a = {a}, b = {b}")

a, b = b, a

print(f"After swapping: a = {a}, b = {b}")
# Out:
# Enter the first number: 5
# Enter the second number: 6
# Before swapping: a = 5.0, b = 6.0
# After swapping: a = 6.0, b = 5.0

# %% [markdown]
# ## Question 3 ( 2 point)
# Write a Python script to determine and print the length of a user-input string.

# %%
# write your answer here

my_string = input("Enter a string: ")

print(f"The length of the string is: {len(my_string)}")
# Out:
# Enter a string: Rakesh
# The length of the string is: 6

# %% [markdown]
# ## Question 4 ( 2 point)
# Design a Python function to check if a number is prime.

# %%
# write your answer here

def is_prime(number):
    if number <= 1:
        return False

    for i in range(2, int(number ** 0.5) + 1):
        if number % i == 0:
            return False

    return True

num = int(input("Enter a number: "))

if is_prime(num):
    print(f"{num} is a prime number.")
else:
    print(f"{num} is not a prime number.")
# Out:
# Enter a number: 8
# 8 is not a prime number.

# %% [markdown]
# ## Question 5 ( 2 point)
# Write a Python program to concatenate following dictionaries to create a new one.
#
# Sample Dictionary : dic1={1:10, 2:20}, dic2={3:30, 4:40}, dic3={5:50,6:60},
#
# Expected Result : {1: 10, 2: 20, 3: 30, 4: 40, 5: 50, 6: 60}

# %%
# write your answer here

dic1 = {1:10, 2:20}
dic2 = {3:30, 4:40}
dic3 = {5:50, 6:60}

result = {}
result.update(dic1)
result.update(dic2)
result.update(dic3)

print("Concatenated Dictionary:", result)
# Out:
# Concatenated Dictionary: {1: 10, 2: 20, 3: 30, 4: 40, 5: 50, 6: 60}
